# %% [markdown]
# 3sum Closet

# %%
nums=[-1,2,1,-4]
target =1
closet=[]
nums.sort()
for i in range(len(nums)):

    left =i+1
    right=len(nums)-1

    while left<right:
        total=nums[i]+nums[left]+nums[right]

        if total>target:
            right-=1
        elif total<target:
            left+=1
    closet.append(total)

for num in closet:
    if num <target:
        print(num)

# %% [markdown]
# 4Sum

# %%
        
        new_list=[]
        nums.sort()
        for anchor in range(len(nums)-3):

            if anchor>0 and nums[anchor]==nums[anchor-1]:
                continue
            for i in range(anchor+1,len(nums)-2):
                if i>anchor+1 and nums[i]==nums[i-1]:
                    continue

                left=i+1
                right=len(nums)-1

                while left<right:
                    total=nums[anchor]+nums[i]+nums[left]+nums[right]

                    if total==target:
                        new_list.append([nums[anchor],nums[i],nums[left],nums[right]])

                        left+=1
                        right-=1

                        while left<right and nums[left]==nums[left-1]:
                            left+=1
                        while left<right and nums[right]==nums[right+1]:
                            right-=1
                    elif total<target:
                        left+=1

                    else:
                        right-=1

        print( new_list)
